# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ruta base donde están los CSV ("." = misma carpeta del notebook)
BASE_PATH = r"data/atlas_charts"  # cámbialo si los tienes en otra carpeta


file_conv_hijos  = f"{BASE_PATH}/conversor_centiles_a_euros_hijos.csv"
file_conv_padres = f"{BASE_PATH}/conversor_centiles_a_euros_padres.csv"
file_tabla_ccaa  = f"{BASE_PATH}/ranking_ccaa_centil_padres_20.csv"

# %%
read_opts = dict(sep=',', encoding='latin1')

conversor_hijos  = pd.read_csv(file_conv_hijos, **read_opts)
conversor_padres = pd.read_csv(file_conv_padres, **read_opts)
tabla_ccaa       = pd.read_csv(file_tabla_ccaa, **read_opts)

# %%
datasets = {
    "conversor_hijos": conversor_hijos,
    "conversor_padres": conversor_padres,
    "tabla_ccaa": tabla_ccaa
}

for nombre, df in datasets.items():
    print(f"\n=== {nombre} ===")
    print("Shape:", df.shape)
    print("Columnas:", list(df.columns)[:12], '...')
# Out:
# === conversor_hijos ===
# Shape: (1400, 2)
# Columnas: ['centil', 'renta'] ...
#
# === conversor_padres ===
# Shape: (700, 2)
# Columnas: ['centil', 'renta'] ...
#
# === tabla_ccaa ===
# Shape: (15, 2)
# Columnas: ['ccaa', 'centil_hijo_loess'] ...

# %%
# AJUSTA ESTOS NOMBRES A TU CSV
COL_PERC = "centil"          # ej.: 'percentil'
COL_EUROS = "renta"             # ej.: 'renta_bruta_euros', 'euros', etc.

tabla_conv_hijos = conversor_hijos[[COL_PERC, COL_EUROS]].dropna()

def centil_hijos_a_euros(c):
    fila = tabla_conv_hijos.loc[tabla_conv_hijos[COL_PERC] == c]
    if fila.empty:
        return np.nan
    return float(fila[COL_EUROS].iloc[0])

centil_hijos_a_euros(20), centil_hijos_a_euros(80)
# Out:
# (8000.825965503149, 28398.894152729776)

# %%
# AJUSTA ESTOS NOMBRES A TU CSV
COL_PERC = "centil"          # ej.: 'percentil'
COL_EUROS = "renta"             # ej.: 'renta_bruta_euros', 'euros', etc.

tabla_conv_padres = conversor_padres[[COL_PERC, COL_EUROS]].dropna()

def centil_padres_a_euros(c):
    fila = tabla_conv_padres.loc[tabla_conv_padres[COL_PERC] == c]
    if fila.empty:
        return np.nan
    return float(fila[COL_EUROS].iloc[0])

centil_padres_a_euros(20), centil_padres_a_euros(80)
# Out:
# (11000.415653057122, 36064.08326340514)

# %%
# AJUSTA ESTOS NOMBRES A TU CSV REAL
COL_CCAA_NOMBRE = "ccaa"  # p.ej.: 'ccaa', 'nombre_ccaa', etc.
COL_P_HIJOS_M = "centil_hijo_loess"
# Reutilizamos COL_P_PADRES y COL_P_HIJOS_M definidos antes

ranking_ccaa = (
    tabla_ccaa.groupby(COL_CCAA_NOMBRE)[COL_P_HIJOS_M]
    .mean()
    .reset_index()
    .sort_values(COL_P_HIJOS_M, ascending=False)
)

ranking_ccaa.head(10)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\Luna\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1791, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1790 try:
# -> 1791     result = self.grouper._cython_operation(
#    1792         "aggregate",
#    1793         values,
#    1794         how,
#    1795         axis=data.ndim - 1,
#    1796         min_count=min_count,
#    1797         **kwargs,
#    1798     )
#    1799 except NotImplementedError:
#    1800     # generally if we have numeric_only=False
#    1801     # and non-applicable functions
#    1802     # try to python agg
#    1803     # TODO: shouldn't min_count matter?
#
# File c:\Users\Luna\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:1039, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038 ngroups = self.ngroups
# ...
